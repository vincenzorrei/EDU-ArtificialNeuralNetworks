# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt

# %%
np.random.seed(42)
X = np.random.rand(100, 1)
y = 2 * X + 1 + 0.1 * np.random.randn(100, 1)

# %%
# Creazione del plot
plt.figure(figsize=(8, 6))
plt.scatter(X, y, color='blue', label='Dati')
plt.plot(X, 2 * X + 1, color='red', label='Linea Reale: y = 2X + 1')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Dati generati per la regressione lineare')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Build a linear regression model
# Definizione del modello per la regressione lineare
model = keras.Sequential([
    layers.InputLayer(input_shape=(1,)),  # Definisce esplicitamente l'input shape
    layers.Dense(1, name='output_layer')  # Output layer
])

# Compile the model
model.compile(
    optimizer='adam', # Optimizer: algoritmo di ottimizzazione
    loss='mse' # mean squared error: errore quadratico medio
)

# Train the model
model.fit(X, y, epochs=1200, verbose=1)
# Out:
# Epoch 1/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 5.3538
# Epoch 2/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4497
# Epoch 3/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3019
# Epoch 4/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1687
# Epoch 5/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0754
# Epoch 6/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3544
# Epoch 7/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2765
# Epoch 8/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9639
# Epoch 9/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3847
# Epoch 10/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2134
# Epoch 11/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3365
# Epoch 12/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1282
# Epoch 13/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0209
# Epoch 14/1200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0818
# Epoch 15/1200
# ...

# %%
# Make predictions
predictions = model.predict(X)

# Plot the results
plt.figure(figsize=(8, 6))

plt.scatter(X, y, color='blue', label='Dati')
plt.plot(X, 2 * X + 1, color='red', label='Linea Reale: y = 2X + 1')
plt.plot(X, predictions, color='darkred', label='Linea Predetta')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Regressione Lineare con TensorFlow')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# Generazione dei dati
np.random.seed(42)
X = np.linspace(0, 2 * np.pi, 250)
y = np.sin(X) + 0.3 * np.random.randn(250)

# Divisione dei dati in train e validation set in modo casuale
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# Definizione del modello
model = keras.Sequential([
    layers.Dense(128, input_dim=1, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(1)
])

# Compilazione del modello
model.compile(optimizer='adam', loss='mean_squared_error')

# Addestramento del modello
history = model.fit(X_train, y_train, epochs=500, validation_data=(X_val, y_val), verbose=1)

# Previsioni
y_train_pred = model.predict(X_train)
y_val_pred = model.predict(X_val)
# Out:
# Epoch 1/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 0.7577 - val_loss: 0.4983
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5094 - val_loss: 0.6039
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5905 - val_loss: 0.4739
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5432 - val_loss: 0.4670
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.5262 - val_loss: 0.4918
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5481 - val_loss: 0.4504
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.5312 - val_loss: 0.4410
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5046 - val_loss: 0.4540
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4766 - val_loss: 0.4091
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5497 - val_loss: 0.3963
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4322 - val_loss: 0.3769
# Epoch 12/500
# ...

# %%
model.summary()
# Out:
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_61 (Dense)                │ (None, 128)            │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,229 (391.52 KB)
#  Trainable params: 33,409 (130.50 KB)
# ...

# %%
# Sort X and y values by X values for better plotting
sort_train_order = X_train.argsort()
X_train = X_train[sort_train_order]
y_train = y_train[sort_train_order]

sort_val_order = X_val.argsort()
X_val = X_val[sort_val_order]
y_val = y_val[sort_val_order]


y_train_pred = y_train_pred[sort_train_order]
y_val_pred = y_val_pred[sort_val_order]



# Plot dei dati e delle previsioni
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(X_train, y_train, label='Train Data', color='blue')
plt.scatter(X_val, y_val, label='Validation Data', color='green')
plt.plot(X_train, y_train_pred, label='Train Predictions', color='red')
plt.plot(X_val, y_val_pred, label='Validation Predictions', color='orange')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Dati e Previsioni')
plt.legend()

# Plot della perdita durante l'addestramento
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoche')
plt.ylabel('Loss')
plt.title('Andamento della Loss durante l\'Addestramento')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Definizione del modello
model = keras.Sequential([
    layers.Dense(128, input_dim=1, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(128, activation='sigmoid'),
    layers.Dense(1)
])

# Compilazione del modello
model.compile(optimizer='adam', loss='mean_squared_error')

# Addestramento del modello
history = model.fit(X_train, y_train, epochs=1000, validation_data=(X_val, y_val), verbose=1)

# Previsioni
y_train_pred = model.predict(X_train)
y_val_pred = model.predict(X_val)
# Out:
# Epoch 1/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 1.6389 - val_loss: 0.6909
# Epoch 2/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7428 - val_loss: 0.6515
# Epoch 3/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6388 - val_loss: 0.4874
# Epoch 4/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6085 - val_loss: 0.4870
# Epoch 5/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5479 - val_loss: 0.5085
# Epoch 6/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6200 - val_loss: 0.5128
# Epoch 7/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5581 - val_loss: 0.4940
# Epoch 8/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5614 - val_loss: 0.4859
# Epoch 9/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5727 - val_loss: 0.5027
# Epoch 10/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5691 - val_loss: 0.5098
# Epoch 11/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5569 - val_loss: 0.4886
# Epoch 12/1000
# ...

# %%
# Sort X and y values by X values for better plotting
sort_train_order = X_train.argsort()
X_train = X_train[sort_train_order]
y_train = y_train[sort_train_order]

sort_val_order = X_val.argsort()
X_val = X_val[sort_val_order]
y_val = y_val[sort_val_order]


y_train_pred = y_train_pred[sort_train_order]
y_val_pred = y_val_pred[sort_val_order]



# Plot dei dati e delle previsioni
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(X_train, y_train, label='Train Data', color='blue')
plt.scatter(X_val, y_val, label='Validation Data', color='green')
plt.plot(X_train, y_train_pred, label='Train Predictions', color='red')
plt.plot(X_val, y_val_pred, label='Validation Predictions', color='orange')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Dati e Previsioni')
plt.legend()

# Plot della perdita durante l'addestramento
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoche')
plt.ylabel('Loss')
plt.title('Andamento della Loss durante l\'Addestramento')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Generazione dei dati
np.random.seed(42)
X = np.linspace(0, 2 * np.pi, 75).reshape(-1, 1)
y = np.sin(X) + 0.2 * np.random.randn(75, 1)


X_train = X[:50]
y_train = y[:50]

X_val = X[50:]
y_val = y[50:]

#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((50, 1), (50, 1), (25, 1), (25, 1))

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split





# Definizione del modello con maggiore complessità
model = keras.Sequential([
    layers.Dense(1024, input_dim=1, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='sigmoid'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1)
])

# Compilazione del modello
model.compile(optimizer='adam', loss='mean_squared_error')

# Addestramento del modello per molte epoche
history = model.fit(X_train, y_train, epochs=200, validation_data=(X_val, y_val), verbose=1)
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 485ms/step - loss: 3.0060 - val_loss: 4.6988
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.4500 - val_loss: 1.5022
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 4.4584 - val_loss: 0.2549
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.6794 - val_loss: 2.5558
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.9057 - val_loss: 5.5507
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 2.1534 - val_loss: 3.2552
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.8149 - val_loss: 0.5892
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.4387 - val_loss: 0.1530
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1.1415 - val_loss: 0.1557
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.7603 - val_loss: 0.7197
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2693 - val_loss: 2.0354
# Epoch 12/200
# ...

# %%
# Previsioni
y_train_pred = model.predict(X_train.reshape(-1, 1))
y_val_pred = model.predict(X_val.reshape(-1, 1))

# Sort X and y values by X values for better plotting
sort_train_order = X_train.argsort()
X_train = X_train[sort_train_order]
y_train = y_train[sort_train_order]

sort_val_order = X_val.argsort()
X_val = X_val[sort_val_order]
y_val = y_val[sort_val_order]


y_train_pred = y_train_pred[sort_train_order]
y_val_pred = y_val_pred[sort_val_order]

# Plot dei dati e delle previsioni
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(X_train, y_train, label='Train Data', color='blue')
plt.scatter(X_val, y_val, label='Validation Data', color='green')
plt.plot(X_train.reshape(-1, 1), y_train_pred.reshape(-1, 1), label='Train Predictions', color='red')
plt.plot(X_val.reshape(-1, 1), y_val_pred.reshape(-1, 1), label='Validation Predictions', color='orange')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Dati e Previsioni')
plt.legend()

# Plot della perdita durante l'addestramento
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoche')
plt.ylabel('Loss')
plt.title('Andamento della Loss durante l\'Addestramento')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
